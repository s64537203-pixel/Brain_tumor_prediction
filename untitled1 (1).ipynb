# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset

# %%
import os

print(path)
# Out:
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset

# %%
os.listdir(path)
# Out:
# ['Training', 'Testing']

# %%
folders=os.listdir(path)
print(folders[0])
# Out:
# Training

# %%
for folder in folders:
  print(folder)
# Out:
# Training
# Testing

# %%
train_path=os.path.join(path,"Training")
test_path=os.path.join(path,"Testing")

# %%
train_path
# Out:
# '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training'

# %%
os.listdir(train_path)
# Out:
# ['pituitary', 'notumor', 'meningioma', 'glioma']

# %%
os.listdir(test_path)
# Out:
# ['pituitary', 'notumor', 'meningioma', 'glioma']

# %%
glioma_path=os.path.join(train_path,"glioma")
meningioma_path=os.path.join(train_path,"meningioma")
notumor_path=os.path.join(train_path,"notumor")
pituitary_path=os.path.join(train_path,"pituitary")

# %%
len(os.listdir(glioma_path))
# Out:
# 1400

# %%
len(os.listdir(meningioma_path))
# Out:
# 1400

# %%
len(os.listdir(notumor_path))
# Out:
# 1400

# %%
len(os.listdir(pituitary_path))
# Out:
# 1400

# %%
classes = os.listdir(train_path)
for class_name in classes :
  print(class_name)
# Out:
# pituitary
# notumor
# meningioma
# glioma

# %%
class_path=os.path.join(train_path,class_name)
class_path
# Out:
# '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/glioma'

# %%
for class_name in classes:
  class_path=os.path.join(train_path,class_name)
  print(class_path)
# Out:
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/notumor
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/meningioma
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/glioma

# %%
classes = os.listdir(train_path)

for class_name in classes:
    class_path = os.path.join(train_path, class_name)
    image_count = len(os.listdir(class_path))

    print(class_name, image_count)
# Out:
# pituitary 1400
# notumor 1400
# meningioma 1400
# glioma 1400

# %%
image_name = os.listdir(glioma_path)[0]

# %%
image_path = os.path.join(glioma_path, image_name)

# %%
from PIL import Image

# %%
img = Image.open(image_path)

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.axis("off")
plt.show()

# %%
classes = os.listdir(train_path)

for class_name in classes:
    class_path = os.path.join(train_path, class_name)
    images = os.listdir(class_path)
    for image_name in images:
      try:
          image_path = os.path.join(class_path, image_name)
          img = Image.open(image_path)
          img.verify()
      except:
          print("Invalid image:", image_path)

# %%
import os
from PIL import Image

# Unique image sizes store karne ke liye set
all_image_sizes = set()

# Training folder ki saari classes
classes = os.listdir(train_path)

# Har class par loop
for class_name in classes:
    class_path = os.path.join(train_path, class_name)

    # Current class ki saari images
    images = os.listdir(class_path)

    # Har image par loop
    for image_name in images:
        image_path = os.path.join(class_path, image_name)

        try:
            # Image open karo
            img = Image.open(image_path)

            # Image ka (width, height) set me add karo
            all_image_sizes.add(img.size)

            # Image close karo
            img.close()

        except Exception as e:
            print(f"❌ Error in image: {image_path}")
            print("Error:", e)

# Saare unique image dimensions print karo
print("Unique Image Sizes:", all_image_sizes)
# Out:
# Unique Image Sizes: {(491, 624), (206, 244), (409, 442), (503, 369), (430, 483), (728, 725), (201, 251), (289, 354), (554, 554), (236, 226), (214, 216), (229, 214), (733, 781), (235, 257), (229, 223), (329, 310), (411, 501), (645, 439), (434, 512), (227, 262), (528, 528), (209, 241), (407, 485), (630, 423), (300, 359), (236, 203), (502, 502), (236, 221), (236, 239), (550, 664), (226, 213), (411, 496), (1024, 830), (235, 261), (374, 456), (329, 314), (355, 452), (626, 686), (276, 326), (300, 345), (210, 213), (359, 449), (201, 250), (192, 192), (221, 228), (236, 216), (225, 225), (410, 490), (202, 223), (605, 613), (216, 234), (208, 248), (350, 350), (444, 506), (450, 446), (442, 442), (339, 340), (534, 674), (257, 307), (421, 486), (224, 219), (341, 377), (402, 396), (926, 649), (213, 237), (341, 395), (825, 993), (236, 220), (235, 233), (622, 777), (494, 600), (208, 243), (228, 221), (239, 248), (600, 605), (314, 260), (201, 249), (341, 372), (224, 223), (212, 236), (1365, 1365), (6
# ...

# %%
print(len(all_image_sizes))
# Out:
# 381

# %%
print(list(all_image_sizes)[:20])
# Out:
# [(491, 624), (206, 244), (409, 442), (503, 369), (430, 483), (728, 725), (201, 251), (289, 354), (554, 554), (236, 226), (214, 216), (229, 214), (733, 781), (235, 257), (229, 223), (329, 310), (411, 501), (645, 439), (434, 512), (227, 262)]

# %%
image_name = os.listdir(glioma_path)[0]

image_path = os.path.join(glioma_path, image_name)

img = Image.open(image_path)

print(img.mode)
# Out:
# L

# %%
images=os.listdir(class_path)
print(type(images))
# Out:
# <class 'list'>

# %%
import matplotlib.pyplot as plt

import random


# ek class choose karte hain
class_name = "glioma"

class_path = os.path.join(train_path, class_name)

# random image select
image_name = random.choice(os.listdir(class_path))

image_path = os.path.join(class_path, image_name)

# image open
img = Image.open(image_path)

plt.imshow(img, cmap="gray")
plt.title(class_name)
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
import os
import random
from PIL import Image

classes = os.listdir(train_path)

plt.figure(figsize=(12,8))

for i, class_name in enumerate(classes):
    class_path = os.path.join(train_path, class_name)

    image_name = random.choice(os.listdir(class_path))
    image_path = os.path.join(class_path, image_name)

    img = Image.open(image_path)

    plt.subplot(2,2,i+1)
    plt.imshow(img, cmap="gray")
    plt.title(class_name)
    plt.axis("off")

plt.show()

# %%
from torchvision import transforms

transform = transforms.Compose([
    transforms.Resize((224, 224)),     # sab images same size
    transforms.Grayscale(num_output_channels=3), # L → 3 channels
    transforms.ToTensor(),             # image → tensor
])

# %%
from torchvision.datasets import ImageFolder

train_dataset = ImageFolder(
    root=train_path,
    transform=transform
)

test_dataset = ImageFolder(
    root=test_path,
    transform=transform
)

# %%
print(train_dataset.class_to_idx)
# Out:
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %%
print(len(train_dataset))
print(len(test_dataset))
# Out:
# 5600
# 1600

# %%
image,label=train_dataset[0]
print(image.shape)
print(label)
# Out:
# torch.Size([3, 224, 224])
# 0

# %%
from torch.utils.data import DataLoader

train_loader=DataLoader(
      train_dataset,
      batch_size=32,
      shuffle=True
  )

test_loader=DataLoader(
      test_dataset,
      batch_size=32,
      shuffle=False
  )

# %%
images,labels=next(iter(train_loader))
print(images.shape)
print(labels.shape)
# Out:
# torch.Size([32, 3, 224, 224])
# torch.Size([32])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cuda

# %%
from torchvision import models
#load pretrained model named ResNet18
model=models.resnet18(weights="DEFAULT")
#freeze all layers initially
for param in model.parameters():
    param.requires_grad=False

#Replace final layer
num_features = model.fc.in_features
#brain tumor classes
model.fc = nn.Linear(num_features,4)
#Move model to GPU
model= model.to(device)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.fc.parameters(),
    lr=0.001
)

# %%
epochs=5
for epoch in range(epochs):
    model.train()
    running_loss=0
    correct=0
    total=0


    for images,labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        outputs=model(images)
        loss=criterion(outputs,labels)
        loss.backward()
        optimizer.step()
        running_loss+=loss.item()
        _,predicted=torch.max(outputs,1)
        total+=labels.size(0)
        correct+=(predicted==labels).sum().item()


accuracy=100*correct/total
print(f"Epoch [{epoch+1}/{epochs}] "
        f"Loss: {running_loss/len(train_loader):.4f} "
        f"Accuracy: {accuracy:.2f}%"
    )
# Out:
# Epoch [5/5] Loss: 0.3227 Accuracy: 88.38%

# %%
model.eval()

correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_accuracy = 100 * correct / total

print(f"Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Test Accuracy: 83.50%

# %%
from sklearn.metrics import confusion_matrix, classification_report

model.eval()

all_preds = []
all_labels = []

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(all_labels, all_preds)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=train_dataset.classes
)

plt.figure(figsize=(8,6))
disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
print(classification_report(
    all_labels,
    all_preds,
    target_names=train_dataset.classes
))

# %%
# Freeze everything
for param in model.parameters():
    param.requires_grad = False

# Unfreeze last ResNet block
for param in model.layer4.parameters():
    param.requires_grad = True

# FC layer bhi train hogi
for param in model.fc.parameters():
    param.requires_grad = True

# %%
for name, param in model.named_parameters():
    if param.requires_grad:
        print(name)
# Out:
# layer4.0.conv1.weight
# layer4.0.bn1.weight
# layer4.0.bn1.bias
# layer4.0.conv2.weight
# layer4.0.bn2.weight
# layer4.0.bn2.bias
# layer4.0.downsample.0.weight
# layer4.0.downsample.1.weight
# layer4.0.downsample.1.bias
# layer4.1.conv1.weight
# layer4.1.bn1.weight
# layer4.1.bn1.bias
# layer4.1.conv2.weight
# layer4.1.bn2.weight
# layer4.1.bn2.bias
# fc.weight
# fc.bias

# %%
import torch.optim as optim

optimizer = optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=1e-4
)

# %%
epochs = 5

for epoch in range(epochs):

    model.train()

    running_loss = 0
    correct = 0
    total = 0

    for images, labels in train_loader:

        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)

        loss = criterion(outputs, labels)

        loss.backward()

        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(train_loader)
    epoch_acc = 100 * correct / total

    print(f"Epoch [{epoch+1}/{epochs}] | Loss: {epoch_loss:.4f} | Accuracy: {epoch_acc:.2f}%")
# Out:
# Epoch [1/5] | Loss: 0.1923 | Accuracy: 92.93%
# Epoch [2/5] | Loss: 0.0383 | Accuracy: 98.66%
# Epoch [3/5] | Loss: 0.0171 | Accuracy: 99.43%
# Epoch [4/5] | Loss: 0.0084 | Accuracy: 99.77%
# Epoch [5/5] | Loss: 0.0091 | Accuracy: 99.73%

# %%
model.eval()

correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_accuracy = 100 * correct / total

print(f"Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Test Accuracy: 93.25%

# %%
from sklearn.metrics import confusion_matrix, classification_report

model.eval()

all_preds = []
all_labels = []

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(all_labels, all_preds)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=train_dataset.classes
)

plt.figure(figsize=(8,6))
disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
print(classification_report(
    all_labels,
    all_preds,
    target_names=train_dataset.classes
))
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.99      0.77      0.86       400
#   meningioma       0.87      0.98      0.92       400
#      notumor       0.91      1.00      0.95       400
#    pituitary       0.99      0.98      0.98       400
#
#     accuracy                           0.93      1600
#    macro avg       0.94      0.93      0.93      1600
# weighted avg       0.94      0.93      0.93      1600

# %%
import random
import matplotlib.pyplot as plt

# Random image choose
index = random.randint(0, len(test_dataset)-1)

image, label = test_dataset[index]

# Display image
plt.imshow(image.permute(1,2,0))
plt.title(f"Actual Class: {train_dataset.classes[label]}")
plt.axis("off")
plt.show()

# %%
model.eval()

# Add batch dimension
input_image = image.unsqueeze(0).to(device)

with torch.no_grad():
    outputs = model(input_image)

    _, prediction = torch.max(outputs, 1)

predicted_class = train_dataset.classes[prediction.item()]

print("Actual Class :", train_dataset.classes[label])
print("Predicted Class :", predicted_class)
# Out:
# Actual Class : meningioma
# Predicted Class : meningioma

# %%
# !pip install grad-cam
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 2.8 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for grad-cam: filename=grad_cam-1.5.5-py3-none-any.whl size=44285 sha256=3e50ae5f7c89a02a9802f1926bbc9043d2f02fd98da85fb0fa855eba956ff995
#   Stored in directory: /root/.cache/pip/wheels/fb/3b/09/2afc520f3d69bc26ae6bd87416759c820a3f7d05c1a077bbf6
# Successfully built grad-cam
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

# %%
target_layers = [model.layer4[-1]]

# %%
input_tensor = image.unsqueeze(0).to(device)

# %%
cam = GradCAM(
    model=model,
    target_layers=target_layers
)

# %%
targets = [ClassifierOutputTarget(prediction.item())]

grayscale_cam = cam(
    input_tensor=input_tensor,
    targets=targets
)

grayscale_cam = grayscale_cam[0]

# %%
img = image.permute(1,2,0).cpu().numpy()

mean = np.array([0.485,0.456,0.406])
std = np.array([0.229,0.224,0.225])

img = std * img + mean
img = np.clip(img,0,1)

# %%
visualization = show_cam_on_image(
    img,
    grayscale_cam,
    use_rgb=True
)

# %%
plt.figure(figsize=(8,8))
plt.imshow(visualization)
plt.title(f"Prediction: {predicted_class}")
plt.axis("off")
plt.show()

# %% [markdown]
# The Grad-CAM visualization shows that the model focused on the tumor region while making its prediction, indicating that the prediction was based on medically relevant image features rather than irrelevant background information.
